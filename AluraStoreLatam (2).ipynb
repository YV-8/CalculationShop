# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ### Tienda 1

# %%
tienda1IngresoTtl = tienda['Precio'].sum()
showt1 = pd.Series({'Ingreso Total': tienda1IngresoTtl})
print(tienda1IngresoTtl)
display(showt1.to_frame())
# Out:
# 1150880400.0
#                           0
# Ingreso Total  1.150880e+09

# %% [markdown]
# ### Tienda 2

# %%
t2IngreTtl = tienda2['Precio'].sum()
showt2 = pd.Series({'Ingreso Total 2': t2IngreTtl})
print(t2IngreTtl)
display(showt2.to_frame())
# Out:
# 1116343500.0
#                             0
# Ingreso Total 2  1.116344e+09

# %% [markdown]
# ### Tienda 3

# %%
t3IngreTtl = tienda3['Precio'].sum()
showt3 = pd.Series({'Ingreso Total 3': t3IngreTtl})
print(showt3)
display(showt3.to_frame())
# Out:
# Ingreso Total 3    1.098020e+09
# dtype: float64
#                             0
# Ingreso Total 3  1.098020e+09

# %% [markdown]
# ### TIenda 4

# %%
t4IngreTtl = tienda4['Precio'].sum()
show4t =pd.Series({'Ingreso Total 4:': t4IngreTtl})
print(t4IngreTtl)
display(show4t.to_frame())
# Out:
# 1038375700.0
#                              0
# Ingreso Total 4:  1.038376e+09

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ### TIenda 1

# %%
groupProdu = tienda.groupby('Categoría del Producto')['Producto'].value_counts()
rename = groupProdu.reset_index(name='Cantidad')
categoria1 = rename.groupby('Categoría del Producto').sum()
categoria1.sort_values('Cantidad', ascending=False)
# Out:
#                                                                   Producto  \
# Categoría del Producto
# Muebles                  ArmarioMesa de nocheSilla de oficinaSofá recli...
# Electrónicos             TV LED UHD 4KImpresoraAuricularesIphone 15Smar...
# Juguetes                 Bloques de construcciónCarrito de control remo...
# Electrodomésticos        MicroondasSecadora de ropaRefrigeradorLavavaji...
# Deportes y diversión     Balón de baloncestoBicicletaVaso térmicoBalón ...
# Instrumentos musicales   BateríaGuitarra eléctricaGuitarra acústicaPand...
# Libros                   Modelado predictivoDashboards con Power BIInic...
# Artículos para el hogar  CuberteríaSet de ollasSet de vasosOlla de presión
#
#                          Cantidad
# Categoría del Producto
# Muebles                       465
# Electrónicos                  448
# Juguetes                      324
# Electrodomésticos             312
# Deportes y diversión          284
# Instrumentos musicales        182
# ...

# %% [markdown]
# ### Tienda 2

# %%
groupProdu2 = tienda2.groupby('Categoría del Producto')['Producto'].value_counts()
rename2 = groupProdu2.reset_index(name='Cantidad')
categoria2 = rename2.groupby('Categoría del Producto').sum()
categoria2.sort_values('Cantidad', ascending=False)
# Out:
#                                                                   Producto  \
# Categoría del Producto
# Muebles                  ArmarioSilla de oficinaCama boxCama kingKit de...
# Electrónicos             Iphone 15TV LED UHD 4KAuriculares con micrófon...
# Juguetes                 Bloques de construcciónMuñeca bebéCarrito de c...
# Electrodomésticos        MicroondasSecadora de ropaLavadora de ropaRefr...
# Deportes y diversión     Cuerda para saltarVaso térmicoBalón de voleibo...
# Instrumentos musicales   BateríaGuitarra acústicaPanderetaGuitarra eléc...
# Libros                   Iniciando en programaciónModelado predictivoCi...
# Artículos para el hogar  Set de ollasSet de vasosOlla de presiónCubertería
#
#                          Cantidad
# Categoría del Producto
# Muebles                       442
# Electrónicos                  422
# Juguetes                      313
# Electrodomésticos             305
# Deportes y diversión          275
# Instrumentos musicales        224
# ...

# %% [markdown]
# ### Tienda 3

# %%
groupProdu3 = tienda3.groupby('Categoría del Producto')['Producto'].value_counts()
rename3 = groupProdu3.reset_index(name='Cantidad')
categoria3 = rename3.groupby('Categoría del Producto').sum()
categoria3.sort_values('Cantidad', ascending=False)
# Out:
#                                                                   Producto  \
# Categoría del Producto
# Muebles                  Kit de bancasCama kingMesa de comedorMesa de n...
# Electrónicos             Smart TVImpresoraTablet ABXYIphone 15Smartwatc...
# Juguetes                 Carrito de control remotoJuego de mesaAjedrez ...
# Electrodomésticos        EstufaLavavajillasRefrigeradorSecadora de ropa...
# Deportes y diversión     Cuerda para saltarBicicletaBalón de baloncesto...
# Libros                   Modelado predictivoCiencia de datos con Python...
# Artículos para el hogar  Set de ollasOlla de presiónCuberteríaSet de vasos
# Instrumentos musicales   PanderetaGuitarra acústicaBateríaGuitarra eléc...
#
#                          Cantidad
# Categoría del Producto
# Muebles                       499
# Electrónicos                  451
# Juguetes                      315
# Electrodomésticos             278
# Deportes y diversión          277
# Libros                        185
# ...

# %% [markdown]
# ### Tienda 4

# %%
groupProdu4 = tienda4.groupby('Categoría del Producto')['Producto'].value_counts()
rename4 = groupProdu4.reset_index(name='Cantidad')
categoria4 = rename4.groupby('Categoría del Producto').sum()
categoria4.sort_values('Cantidad', ascending=False)
# Out:
#                                                                   Producto  \
# Categoría del Producto
# Muebles                  Cama boxCama kingMesa de comedorMesa de nocheS...
# Electrónicos             Smart TVAsistente virtualImpresoraIphone 15Tab...
# Juguetes                 Carrito de control remotoBloques de construcci...
# Deportes y diversión     Balón de baloncestoBalón de voleibolVaso térmi...
# Electrodomésticos        MicroondasEstufaLavavajillasSecadora de ropaLa...
# Artículos para el hogar  CuberteríaSet de ollasOlla de presiónSet de vasos
# Libros                   Dashboards con Power BIModelado predictivoInic...
# Instrumentos musicales   PanderetaBateríaGuitarra acústicaGuitarra eléc...
#
#                          Cantidad
# Categoría del Producto
# Muebles                       480
# Electrónicos                  451
# Juguetes                      338
# Deportes y diversión          277
# Electrodomésticos             254
# Artículos para el hogar       201
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# ### Calificacion Tienda 1

# %%
calificacion1= tienda.groupby('Producto')['Calificación'].mean().round(2)
calificacion1
# Out:
# Producto
# Ajedrez de madera              4.43
# Armario                        3.95
# Asistente virtual              4.08
# Auriculares                    3.64
# Auriculares con micrófono      3.97
# Balón de baloncesto            3.87
# Balón de voleibol              4.07
# Batería                        4.19
# Bicicleta                      3.94
# Bloques de construcción        4.09
# Cama box                       4.11
# Cama king                      3.77
# Carrito de control remoto      4.13
# Celular ABXY                   3.82
# Ciencia de datos con Python    4.10
# Cubertería                     4.23
# Cubo mágico 8x8                4.07
# Cuerda para saltar             3.62
# Dashboards con Power BI        3.95
# Dinosaurio Rex                 3.78
# Estufa                         4.13
# Guitarra acústica              3.96
# Guitarra eléctrica             4.09
# Impresora                      4.17
# Iniciando en programación      4.29
# Iphone 15                      3.94
# ...

# %% [markdown]
# ### Calificacion Tienda 2

# %%
calificacion2 = tienda2.groupby('Producto')['Calificación'].mean().round(2)
display(calificacion2.to_frame())

# %% [markdown]
# ### Calificacion  Tienda 3

# %%
calificacion3 = tienda3.groupby('Producto')['Calificación'].mean().round(2)
display(calificacion3.to_frame())

# %% [markdown]
# ### Calificacion Tienda 4

# %%
calificacion4 = tienda4.groupby('Producto')['Calificación'].mean().round(2)
display(calificacion4.to_frame())

# %% [markdown]
# ### Calificación promedio general por tienda

# %%
calpromedio1 = tienda['Calificación'].mean().round(2)
calpromedio2 = tienda2['Calificación'].mean().round(2)
calpromedio3 = tienda3['Calificación'].mean().round(2)
calpromedio4 = tienda4['Calificación'].mean().round(2)

calificaciones_totales = pd.DataFrame({'Tienda': ['Tienda 1', 'Tienda 2',
                                                  'Tienda 3', 'Tienda 4'],
                                       'Calificación Promedio': [
                                           calpromedio1,
                                           calpromedio2,
                                           calpromedio3,
                                           calpromedio4]})

display(calificaciones_totales)
# Out:
#      Tienda  Calificación Promedio
# 0  Tienda 1                   3.98
# 1  Tienda 2                   4.04
# 2  Tienda 3                   4.05
# 3  Tienda 4                   4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
groupP = tienda.groupby('Producto')['Producto'].value_counts()
productosMasVendidos1 = groupP.sort_values(ascending=False)
result = productosMasVendidos1.to_frame(name='Cantidad')
result1 = result.head(10)
result1.plot(kind='bar',figsize=(12,8), color=('skyblue'))
# Out:
# <Axes: xlabel='Producto'>

# %%
result1t1 = result.tail(10)
result1t1.plot(kind='bar',figsize=(12,8), color=('lightcoral'))
# Out:
# <Axes: xlabel='Producto'>

# %% [markdown]
# ## tienda 2

# %%
groupP2 = tienda2.groupby('Producto')['Producto'].value_counts()
productosMasVendidos2 = groupP2.sort_values(ascending=False)
result2 = productosMasVendidos2.to_frame(name='Cantidad')
result2t = result2.head(10)
result2t.plot(kind='bar',figsize=(12,8), color=('skyblue'))
# Out:
# <Axes: xlabel='Producto'>

# %%
result2t2 = result2.tail(10)
result2t2.plot(kind='bar',figsize=(12,8), color=('lightcoral'))
# Out:
# <Axes: xlabel='Producto'>

# %% [markdown]
# ### Tienda 3

# %%
groupP3 = tienda3.groupby('Producto')['Producto'].value_counts()
productosMasVendidos3 = groupP3.sort_values(ascending=False)
result3 = productosMasVendidos3.to_frame(name='Cantidad')
result3t = result3.head(10)
result3t.plot(kind='bar',figsize=(12,8), color=('skyblue'))
# Out:
# <Axes: xlabel='Producto'>

# %%
result3t3 = result3.tail(10)
result3t3.plot(kind='bar',figsize=(12,8), color=('lightcoral'))
# Out:
# <Axes: xlabel='Producto'>

# %% [markdown]
# ### Tienda 4

# %%
groupP4 = tienda4.groupby('Producto')['Producto'].value_counts()
productosMasVendidos4 = groupP4.sort_values(ascending=False)
result4 = productosMasVendidos4.to_frame(name='Cantidad')
result4t = result4.head(10)
result4t.plot(kind='bar',figsize=(12,8), color=('skyblue'))
# Out:
# <Axes: xlabel='Producto'>

# %%
result4t4 = result4.tail(10)
result4t4.plot(kind='bar',figsize=(12,8), color=('lightcoral'))
# Out:
# <Axes: xlabel='Producto'>

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# ### tienda1

# %%
prom1 = tienda['Costo de envío'].mean().round(2)
prom2 = tienda2['Costo de envío'].mean().round(2)
prom3 = tienda3['Costo de envío'].mean().round(2)
prom4 = tienda4['Costo de envío'].mean().round(2)

promedio_envio = pd.DataFrame({'Promedio Costo de Envío': [prom1, prom2, prom3, prom4],
                               'Tienda': ['Tienda 1', 'Tienda2', 'Tienda 3', 'Tienda 4']})

display(promedio_envio)
# Out:
#    Promedio Costo de Envío    Tienda
# 0                 26018.61  Tienda 1
# 1                 25216.24   Tienda2
# 2                 24805.68  Tienda 3
# 3                 23459.46  Tienda 4

# %% [markdown]
# # Graficos:

# %% [markdown]
# ### 1.Grafico
# Ingresos de la tienda

# %%
ingresosTienda = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Ingreso Total': [tienda1IngresoTtl, t2IngreTtl, t3IngreTtl, t4IngreTtl]
})
ingresosTienda =ingresosTienda.plot(kind='bar', x='Tienda', y='Ingreso Total', color=('skyblue'))

# %% [markdown]
# ### 2.Graficos
#
# distribucion de categorias de productos

# %%
showcategoria1 = categoria1['Cantidad'].plot(kind='pie', figsize=(8, 8),
                                             autopct='%1.1f%%', startangle=90,
                                             pctdistance=0.85)

# %%
showcategoria2 = categoria2['Cantidad'].plot(kind='pie', figsize=(8, 8),
                                             autopct='%1.1f%%', startangle=90,
                                             pctdistance=0.85)

# %%
showcategoria3 = categoria3['Cantidad'].plot(kind='pie', figsize=(8, 8),
                                             autopct='%1.1f%%', startangle=90,
                                             pctdistance=0.85)

# %%
showcategoria4 = categoria4['Cantidad'].plot(kind='pie', figsize=(8, 8),
                                             autopct='%1.1f%%', startangle=90,
                                             pctdistance=0.85)

# %% [markdown]
# ### 3.Graficos
# Opiniones de los mas vendidos

# %%
calificaciones_totales = calificaciones_totales.plot(kind ='line', x='Tienda', y='Calificación Promedio', color=('skyblue'))

# %%
tienda['Ingreso Neto'] = tienda['Precio'] - tienda['Costo de envío']
tienda2['Ingreso Neto'] = tienda2['Precio'] - tienda2['Costo de envío']
tienda3['Ingreso Neto'] = tienda3['Precio'] - tienda3['Costo de envío']
tienda4['Ingreso Neto'] = tienda4['Precio'] - tienda4['Costo de envío']
promediIngre1 =tienda['Ingreso Neto'].mean().round(2)
promediIngre2 =tienda2['Ingreso Neto'].mean().round(2)
promediIngre3 = tienda3['Ingreso Neto'].mean().round(2)
promediIngre4 = tienda4['Ingreso Neto'].mean().round(2)
promedioIngresos = pd.DataFrame({'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
                                 'Ingreso Neto Promedio': [promediIngre1, promediIngre2, promediIngre3, promediIngre4]})
display(promedioIngresos)
# Out:
#      Tienda  Ingreso Neto Promedio
# 0  Tienda 1              461849.30
# 1  Tienda 2              448011.19
# 2  Tienda 3              440654.09
# 3  Tienda 4              416903.44

# %% [markdown]
# # Informe de tiendas
# Viendo el resultados de  cada una de las tiendas se puede  puede ver uan diferencia entre el ingreso de cada una de las tiendas, las categorias que mas vende, opiniones de la gente y los productos mas vendidos.
#
# ### Ingrseos de las tiendas
# En los ingresos de las tiendas se ve claramente en la grafica podemso ver que el ingreso de cada tienda es por arriba de 1.2 len 9 pero hay uno que esta por bajo de los demas que es la tienda 4 como muestra la grafica:
# ![Screenshot from 2026-01-07 18-38-32.png](data:image/png;base64,...)
#
# ## Categoria de productos vendidos en cada tienda
#
# Para eso tenemos que ver tambien la grafica de las categorias de los productos mas vendidos, en eso  podemos ver que en la grafica:
#
# ### Tienda 1:
#
# ![Screenshot from 2026-01-07 18-45-23.png](data:image/png;base64,...)
#
# ### Tienda 2:
#
# ![Screenshot from 2026-01-07 18-45-12.png](data:image/png;base64,...)
#
# ### Tienda 3:
#
# ![Screenshot from 2026-01-07 18-45-02.png](data:image/png;base64,...)
#
# ### Tienda 4:
#
# ![Screenshot from 2026-01-07 18-44-54.png](data:image/png;base64,...)
#
# Con esto nos dammos cuanta que las 3 primeras tiendas venden casi lo mismo pero la ultima tienda es un poco menos; pero por otro lado cuando vemos la parte de las calificaciones de  cada tienda  cambia el como la decision:
#
# ### Calificaciones
# ![Screenshot from 2026-01-07 18-35-01.png](data:image/png;base64,...)
#
# Teniendo en cuenta estos analisis tenemos que reflexionar si el  ingreso de la tienda 1 equivale a que las calificaciones sean  bajas o si por lo contrario la tienda 4  que no tiene tantos ingresos como muestra en la grafica:
# ![Screenshot from 2026-01-07 19-46-20.png](data:image/png;base64,...)
#
# Entonces viendo la grafica que es el ingreso neto a cada tienda seria bueno que el empresario vea la opcion de cerrar la tienda 4 por que no ingresa mucho a contrairo ide la tienda 1 pero si se podria ubicar mejor a los empleados de la tienda 4 a la tienda 1  por la calificacion de sus clientes para mejorar a los clientes
